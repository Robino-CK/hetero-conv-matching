# %%
import dgl

from Coarsener.HeteroRGCNCoarsener import HeteroRGCNCoarsener
from Data.DBLP import DBLP
from Data.Citeseer import Citeseer

import dgl.function as fn
import torch
import numpy as np
import torch_geometric
torch.cuda.empty_cache()
# Out:
# /storage/scratch/0994359/hetero-conv-matching/.venv/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
dataset = Citeseer() 
original_graph = dataset.load_graph(n_components=30)
device= "cuda:0"
original_graph = original_graph.to(device)
# Out:
#   NumNodes: 3327
#   NumEdges: 9228
#   NumFeats: 3703
#   NumClasses: 6
#   NumTrainingSamples: 120
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.

# %%
import torch, math
from torch import nn
import pickle
class Tnet(nn.Module):                          # critic network
    def __init__(self, dx, dy, h=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dx+dy, h), nn.ReLU(),
            nn.Linear(h, h), nn.ReLU(),
            nn.Linear(h, 1))
    def forward(self, x, y):                    # x,y: (n, d)
        return self.net(torch.cat([x, y], 1))

def mi_mine(x, y, t_net, iters=500, lr=1e-4):
    opt = torch.optim.Adam(t_net.parameters(), lr)
    for _ in range(iters):
        # shuffle to create “negative” pairs
        y_perm = y[torch.randperm(len(y))]
        t = t_net(x, y).mean()
        et = torch.exp(t_net(x, y_perm)).mean()
        loss = -(t - torch.log(et))
        opt.zero_grad(); loss.backward(); opt.step()
    return (t - torch.log(et)).item() / math.log(2)
file = 'results/DBLP_CLL_pca_30_5_pairs_0/1.0'
with open(file, 'rb') as fh:
    coarsener = pickle.load(fh) 
sum_graph = coarsener.summarized_graph
X = sum_graph.nodes["author"].data["feat_pca"]
Y = sum_graph.nodes["author"].data["hauthortopaper"]
tn = Tnet(X.shape[1], Y.shape[1]).to("cuda:0")
mi_mine(X,Y, tn)
# Out:
# 2.830621518680062

# %%
import torch, math
from torch import nn
import pickle
class Tnet(nn.Module):                          # critic network
    def __init__(self, dx, dy, h=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dx+dy, h), nn.ReLU(),
            nn.Linear(h, h), nn.ReLU(),
            nn.Linear(h, 1))
    def forward(self, x, y):                    # x,y: (n, d)
        return self.net(torch.cat([x, y], 1))

def mi_mine(x, y, t_net, iters=500, lr=1e-4):
    opt = torch.optim.Adam(t_net.parameters(), lr)
    for _ in range(iters):
        # shuffle to create “negative” pairs
        y_perm = y[torch.randperm(len(y))]
        t = t_net(x, y).mean()
        et = torch.exp(t_net(x, y_perm)).mean()
        loss = -(t - torch.log(et))
        opt.zero_grad(); loss.backward(); opt.step()
    return (t - torch.log(et)).item() / math.log(2)
file = 'results/ACM_CLL_pca_30_5_pairs_0/1.0'
with open(file, 'rb') as fh:
    coarsener = pickle.load(fh) 
sum_graph = coarsener.summarized_graph
X = sum_graph.nodes["paper"].data["feat_pca"]
Y = sum_graph.nodes["paper"].data["hpapertoauthor"]
tn = Tnet(X.shape[1], Y.shape[1]).to("cuda:0")
mi_mine(X,Y, tn)
# Out:
# 4.916342836845282

# %%
import torch

def neighbour_purity_torch(R, labels, k=5, p=2):
    """
    R      : (m × d) float tensor on any device
    labels : (m,)   int/str tensor (cast to long/int)
    p      : 2 → Euclidean, 1 → Manhattan, etc.
    """
    # pairwise distances (m × m)
    dist = torch.cdist(R, R, p=p)
    dist.fill_diagonal_(float('inf'))              # ignore self-distance

    # k smallest distances
    idx = dist.topk(k, largest=False).indices      # (m × k)

    # label agreement
    same = labels.unsqueeze(1).expand_as(idx) == labels[idx]

    # convert to float before mean
    return same.float().mean().item()

# %%
import pickle
file = 'results/Citeseer_CLL_pca_30/0.1'
with open(file, 'rb') as fh:
    coarsener = pickle.load(fh) 
sum_graph = coarsener.summarized_graph
X = sum_graph.nodes["paper"].data["feat_pca"]
Y = sum_graph.nodes["paper"].data["hcites"]

X_c, Y_c = coarsener.ccas["cites"].transform(X,Y)
du = sum_graph.nodes["paper"].data[f"deg_cites"] + 1
R = X_c / du.unsqueeze(-1) + Y_c
labels = sum_graph.nodes["paper"].data["label"]
neighbour_purity_torch(R.to("cpu"), labels.to("cpu"))
# Out:
# 0.9780488014221191

# %%
import pickle
file = 'results/Citeseer_None_pca_64CONV/0.1'
with open(file, 'rb') as fh:
    coarsener = pickle.load(fh) 
sum_graph = coarsener.summarized_graph
X = sum_graph.nodes["paper"].data["feat_pca"]
Y = sum_graph.nodes["paper"].data["hcites"]

#X_c, Y_c = coarsener.ccas["cites"].transform(X,Y)
#du = sum_graph.nodes["paper"].data[f"deg_cites"] + 1
R = X +Y 
labels = sum_graph.nodes["paper"].data["label"]
neighbour_purity_torch(R.to("cpu"), labels.to("cpu"))
# Out:
# 0.9969788789749146

# %%
# Out:
# 0.6531645655632019

# %%
import pickle
def plot_scatter(file, cca=None,is_add=True, save_path=None, show_plot=False):
    with open(file, 'rb') as fh:
        coarsener = pickle.load(fh) 
    print(file)
    sum_graph = coarsener.summarized_graph
    sum_graph.nodes["paper"].data.keys()
    X = sum_graph.nodes["paper"].data["feat_pca"]
    Y = sum_graph.nodes["paper"].data["hcites"]
    du = sum_graph.nodes["paper"].data[f"deg_cites"] + 1
    labels = sum_graph.nodes["paper"].data["label"]
    if is_add:
        R = X + Y
    else:
        if cca:
            X_c, Y_c = cca.transform(X,Y)
        else:
            X_c, Y_c = coarsener.ccas["cites"].transform(X,Y)
        
        R = X_c / du.unsqueeze(-1) + Y_c
    print("k=1", neighbour_purity_torch(R.to("cpu"), labels.to("cpu"), k=7))
    print("k=3", neighbour_purity_torch(R.to("cpu"), labels.to("cpu"), k=3))
    print("k=5", neighbour_purity_torch(R.to("cpu"), labels.to("cpu"), k=5))
    print("k=7", neighbour_purity_torch(R.to("cpu"), labels.to("cpu"), k=7))
    import torch
    import matplotlib.pyplot as plt
    from sklearn.decomposition import PCA
    # Example data
    data = R.cpu()
    mapping = coarsener.get_mapping('paper')
    labels_dict = coarsener.get_labels(mapping, 'paper')
    size = max(labels_dict.keys()) + 1

    # Create a tensor of zeros
    labels = torch.zeros(size, dtype=torch.int64)

    # Fill the tensor with the dictionary values at the corresponding indices
    for idx, value in labels_dict.items():
        labels[idx] = value

    # Create a tensor of zeros
    

    data_np = data.numpy()
    print(np.max(data_np))
    # Perform PCA
    pca = PCA(n_components=2)
    reduced = pca.fit_transform(data_np)  # Shape: (3652, 2)
    sizes = [5, 5, 5, 5]
    # Plot with color by label
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(reduced[:, 0], reduced[:, 1], c=labels.numpy(), cmap='tab10', alpha=0.7, sizes=sizes)
    plt.xlabel("PCA Component 1")
    plt.ylabel("PCA Component 2")
    plt.title("Embedding")
    plt.grid(True)
 #   plt.colorbar(scatter, label='Label')
    if save_path:
        plt.savefig(save_path)
    if show_plot:
        
        plt.show()

# %%
plot_scatter('results/Citeseer_CLL_pca_30/1.0',is_add=False,save_path="plots/scatter_cit_cll_1")
plot_scatter('results/Citeseer_CLL_pca_30/0.5', is_add=False,save_path="plots/scatter_cit_cll_05")
plot_scatter('results/Citeseer_CLL_pca_30/0.3',is_add=False,save_path="plots/scatter_cit_cll_03")
plot_scatter('results/Citeseer_CLL_pca_30/0.1',is_add=False,save_path="plots/scatter_cit_cll_01")

plot_scatter('results/Citeseer_None_pca_64CONV/1.0',is_add=True,save_path="plots/scatter_cit_conv_1")
plot_scatter('results/Citeseer_None_pca_64CONV/0.5', is_add=True,save_path="plots/scatter_cit_conv_05")
plot_scatter('results/Citeseer_None_pca_64CONV/0.3',is_add=True,save_path="plots/scatter_cit_conv_03")
plot_scatter('results/Citeseer_None_pca_64CONV/0.1',is_add=True,save_path="plots/scatter_cit_conv_01")
# Out:
# results/Citeseer_CLL_pca_30/1.0
# k=1 0.6418668627738953
# k=3 0.673799455165863
# k=5 0.6531645655632019
# k=7 0.6418668627738953
# 0.5511637
# results/Citeseer_CLL_pca_30/0.5
# k=1 0.46307799220085144
# k=3 0.4977858364582062
# k=5 0.47173914313316345
# k=7 0.46307799220085144
# 0.5278743
# results/Citeseer_CLL_pca_30/0.3
# k=1 0.632038950920105
# k=3 0.6559678912162781
# k=5 0.6393179297447205
# k=7 0.632038950920105
# 0.5278743
# results/Citeseer_CLL_pca_30/0.1
# k=1 0.9786585569381714
# k=3 0.9786585569381714
# k=5 0.9780488014221191
# k=7 0.9786585569381714
# 0.5495393
# results/Citeseer_None_pca_64CONV/1.0
# k=1 0.5639934539794922
# k=3 0.6257520914077759
# k=5 0.5855595469474792
# k=7 0.5639934539794922
# 0.146907
# results/Citeseer_None_pca_64CONV/0.5
# k=1 0.4640275239944458
# k=3 0.4797188639640808
# k=5 0.4691566228866577
# k=7 0.4640275239944458
# 0.146907
# results/Citeseer_None_pca_64CONV/0.3
# k=1 0.7181583642959595
# k=3 0.7289156913757324
# k=5 0.7244979739189148
# k=7 0.7181583642959595
# 0.146907
# results/Citeseer_None_pca_64CONV/0.1
# k=1 0.9969788789749146
# k=3 0.9969788789749146
# k=5 0.9969788789749146
# k=7 0.9969788789749146
# 0.12149935

# %%
plot_scatter('results/Cora_CLL_0/1.0', is_add=False,save_path="plots/scatter_cora_cll_1")
plot_scatter('results/Cora_CLL_0/0.5',is_add=False,save_path="plots/scatter_cora_cll_05")
plot_scatter('results/Cora_CLL_0/0.3', is_add=False, save_path="plots/scatter_cora_cll_03")
plot_scatter('results/Cora_CLL_0/0.1', is_add=False, save_path="plots/scatter_cora_cll_01")



plot_scatter('results/Cora_None_CONV/1.0', is_add=True,save_path="plots/scatter_cora_conv_1")
plot_scatter('results/Cora_None_CONV/0.5',is_add=True,save_path="plots/scatter_cora_conv_05")
plot_scatter('results/Cora_None_CONV/0.3', is_add=True, save_path="plots/scatter_cora_conv_03")
plot_scatter('results/Cora_None_CONV/0.1', is_add=True, save_path="plots/scatter_cora_conv_01")
# Out:
# results/Cora_CLL_0/1.0
# k=1 0.6800127029418945
# k=3 0.7447859048843384
# k=5 0.705590546131134
# k=7 0.6800127029418945
# 1.0850453
# results/Cora_CLL_0/0.5
# k=1 0.6152465343475342
# k=3 0.6341463327407837
# k=5 0.6300073862075806
# k=7 0.6152465343475342
# 1.0850455
# results/Cora_CLL_0/0.3
# k=1 0.6665492057800293
# k=3 0.6806411743164062
# k=5 0.6747225522994995
# k=7 0.6665492057800293
# 1.060632
# results/Cora_CLL_0/0.1
# k=1 0.9307036399841309
# k=3 0.93034827709198
# k=5 0.9291045069694519
# k=7 0.9307036399841309
# 1.0526621
# results/Cora_None_CONV/1.0
# k=1 0.6974665522575378
# k=3 0.774034321308136
# k=5 0.733802318572998
# k=7 0.6974665522575378
# 1.5
# results/Cora_None_CONV/0.5
# k=1 0.6733333468437195
# k=3 0.6575308442115784
# k=5 0.6678518652915955
# k=7 0.6733333468437195
# 0.90555555
# results/Cora_None_CONV/0.3
# k=1 0.8930784463882446
# k=3 0.8884758353233337
# k=5 0.8902106285095215
# k=7 0.8930784463882446
# 0.90555555
# results/Cora_None_CONV/0.1
# k=1 1.0
# k=3 1.0
# k=5 1.0
# k=7 1.0
# 0.6203787

# %%
import matplotlib.pyplot as plt

import pickle
def plot_bar(file, save_path=None):
    with open(file, 'rb') as fh:
        coarsener_new = pickle.load(fh) 
    original_graph = coarsener_new.original_graph
    sum_graph = coarsener_new.summarized_graph
    sum_graph.nodes["paper"].data.keys()
    
    # Example data
    
    
    # print(sum_graph.nodes["paper"].data["label"])
    
    # print(torch.sum(torch.bincount(original_graph.nodes["paper"].data["label"].to('cpu'))))
    # print(torch.bincount(sum_graph.nodes["paper"].data["label"].to('cpu')))
    
    mapping = coarsener_new.get_mapping('paper')
    labels = coarsener_new.get_labels(mapping, 'paper')
    size = max(labels.keys()) + 1

    # Create a tensor of zeros
    label_tensor = torch.zeros(size, dtype=torch.int64)

    # Fill the tensor with the dictionary values at the corresponding indices
    for idx, value in labels.items():
        label_tensor[idx] = value
    
    base_heights = torch.bincount(original_graph.nodes["paper"].data["label"].to('cpu'))    # Bottom (larger) bars
    top_heights = torch.bincount(label_tensor)    # Top (smaller) bars
    print(base_heights)
    print(top_heights)
    
    cmap = plt.get_cmap('tab10')
    labels = ['A', 'B', 'C', 'D', 'E', 'F']
    x = range(len(labels))

    # Plot bars using a loop
    for i in x:
        color = cmap(i % 10)  # Get color from tab10
        # Plot bottom (original graph) bar
        plt.bar(i, base_heights[i], color=color, alpha=0.3, label='Original' if i == 0 else "")
        # Plot top (summarized graph) bar stacked on top
        plt.bar(i, top_heights[i], color=color, alpha=1.0, label='Summarized' if i == 0 else "")

    # Add labels
    plt.xticks(x, labels)
    plt.ylabel('Count')
    plt.title('Number of nodes per label before and after reduction')
    plt.legend()
    
    if save_path:
        plt.savefig(save_path)
    plt.show()

#     # Add labels
#     plt.xticks(x, labels)
#     plt.ylabel('Height')
#     plt.title('Stacked Bar Plot (Top Smaller) ')

#     plt.show()
#  #   plt.colorbar(scatter, label='Label')
#     if save_path:
#         plt.savefig(save_path)
#     plt.show()

# %%
with open('results/cit_clnl_pca_10/0.5', 'rb') as fh:
        coarsener_new = pickle.load(fh) 
print(torch.bincount(coarsener_new.original_graph.nodes["paper"].data["label"].to('cpu')))
# Out:
# tensor([264, 590, 668, 701, 596, 508])

# %%
plot_bar( 'results/cit_clnl_pca_10/0.5', save_path="plots/bar_cl_05")
plot_bar( 'results/cit_clnl_pca_10/0.1', save_path="plots/bar_cl_01")
# Out:
# tensor([264, 590, 668, 701, 596, 508])
# tensor([112, 310, 355, 361, 313, 212])
# tensor([264, 590, 668, 701, 596, 508])
# tensor([23, 71, 47, 84, 57, 49])

# %%
plot_bar( 'results/cit_convmatch_metrics/0.5', save_path="plots/bar_conv_05")
plot_bar( 'results/cit_convmatch_metrics/0.1', save_path="plots/bar_conv_01")
# Out:
# tensor([264, 590, 668, 701, 596, 508])
# tensor([124, 279, 365, 348, 301, 242])
# tensor([264, 590, 668, 701, 596, 508])
# tensor([24, 60, 50, 78, 58, 58])

# %%
plot_bar('results/cit_convmatch_metrics/0.5')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plot_bar('results/cit_convmatch_metrics/0.5')
#
# Cell In[8], line 5, in plot_bar(file, save_path)
#       4 def plot_bar(file, save_path=None):
# ----> 5     with open(file, 'rb') as fh:
#       6         coarsener_new = pickle.load(fh)
#       7     original_graph = coarsener_new.original_graph
#
# File /scratch/0994359/hetero-conv-matching/.venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/cit_convmatch_metrics/0.5'

# %%
import pickle
with open(f'results/cit_cl_pca_10/0.5', 'rb') as fh:
    coarsener = pickle.load(fh) 
with open(f'results/cit_cl_pca_10/0.99', 'rb') as fh:
    coarsener_begin = pickle.load(fh) 
sum_graph = coarsener.summarized_graph
sum_graph.nodes["paper"].data.keys()
X = sum_graph.nodes["paper"].data["feat_pca"]
Y = sum_graph.nodes["paper"].data["hcites"]

from Projections.ContrastiveLearner import ContrastiveLearner
cl = ContrastiveLearner(X.shape[1], Y.shape[1])
orig_graph = coarsener_begin.summarized_graph

X_sum = orig_graph.nodes["paper"].data["feat_pca"]
Y_sum = orig_graph.nodes["paper"].data["hcites"]

#cl.fit(X,Y)
cl.fit(X_sum, Y_sum)

X_c, Y_c = coarsener.ccas["cites"].transform(X,Y)

du = sum_graph.nodes["paper"].data[f"deg_cites"]
print(du.unsqueeze(-1).shape)
R = X_c / du.unsqueeze(-1) + Y_c
print(R.shape)
import torch
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# Example data
data = R.cpu()
labels =sum_graph.nodes["paper"].data["label"].cpu()

# Get the first two dimensions

data_np = data.numpy()

# Perform PCA
pca = PCA(n_components=2)
reduced = pca.fit_transform(data_np)  # Shape: (3652, 2)
sizes = [5, 5, 5, 5]
# Plot with color by label
plt.figure(figsize=(8, 6))
scatter = plt.scatter(reduced[:, 0], reduced[:, 1], c